# %% [markdown]
# <a href="https://colab.research.google.com/github/sukrucakmak/probability-for-discrete-systems/blob/main/PermutationCombination.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Permutation
# In mathematics, a permutation of a set is, loosely speaking, an arrangement of its members into **a sequence** or **linear order**, or if the set is already ordered, a rearrangement of its elements. The word "permutation" also refers to the act or process of changing the linear order of an ordered set.
#
# ### Question
#
# In how many ways can 6 people sit in 3 seats next to each other?
#
#
# ### Answer

# %%
from math import factorial
from itertools import permutations

# Get all permutations of ['A', 'B','C','D','E','F']
perm = permutations(['A', 'B','C','D','E','F'], 3)

# Print the obtained permutations
for i in list(perm):
    print (i)

# Calculate number of permutations
print(sum(1 for count in perm))
# Out:
# ('A', 'B', 'C', 'D', 'E', 'F')
# ('A', 'B', 'C', 'D', 'F', 'E')
# ('A', 'B', 'C', 'E', 'D', 'F')
# ('A', 'B', 'C', 'E', 'F', 'D')
# ('A', 'B', 'C', 'F', 'D', 'E')
# ('A', 'B', 'C', 'F', 'E', 'D')
# ('A', 'B', 'D', 'C', 'E', 'F')
# ('A', 'B', 'D', 'C', 'F', 'E')
# ('A', 'B', 'D', 'E', 'C', 'F')
# ('A', 'B', 'D', 'E', 'F', 'C')
# ('A', 'B', 'D', 'F', 'C', 'E')
# ('A', 'B', 'D', 'F', 'E', 'C')
# ('A', 'B', 'E', 'C', 'D', 'F')
# ('A', 'B', 'E', 'C', 'F', 'D')
# ('A', 'B', 'E', 'D', 'C', 'F')
# ('A', 'B', 'E', 'D', 'F', 'C')
# ('A', 'B', 'E', 'F', 'C', 'D')
# ('A', 'B', 'E', 'F', 'D', 'C')
# ('A', 'B', 'F', 'C', 'D', 'E')
# ('A', 'B', 'F', 'C', 'E', 'D')
# ('A', 'B', 'F', 'D', 'C', 'E')
# ('A', 'B', 'F', 'D', 'E', 'C')
# ('A', 'B', 'F', 'E', 'C', 'D')
# ('A', 'B', 'F', 'E', 'D', 'C')
# ('A', 'C', 'B', 'D', 'E', 'F')
# ('A', 'C', 'B', 'D', 'F', 'E')
# ('A', 'C', 'B', 'E', 'D', 'F')
# ('A', 'C', 'B', 'E', 'F', 'D')
# ('A', 'C', 'B', 'F', 'D', 'E')
# ('A', 'C', 'B', 'F', 'E', 'D')
# ...

# %% [markdown]
# # Combination
#
# In mathematics, a combination is **a selection of items from a set that has distinct members**, such that the order of selection does not matter (unlike permutations).
#
# ### Question
#
# In how many ways can 3 people be chosen from 8 people?
#
# ### Answer

# %%
from itertools import combinations

comb = combinations(range(8),3)

print(sum(1 for count in comb))
# Out:
# 56
